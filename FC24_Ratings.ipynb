# %% [markdown]
# <a href="https://colab.research.google.com/github/sunnypaajee/FIFA_Rating_Model/blob/main/FC24_Ratings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Web Scraping
from urllib.request import Request, urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup

# Time
from datetime import date
from time import sleep

# %%
url = "https://www.futbin.com/players?page=1&version=gold_rare&pos_type=all"

headers = {'User-Agent': 'Mozilla/5.0'}
req = Request(url, headers=headers)
response = urlopen(req)
html = response.read()


soup = BeautifulSoup(html, 'html.parser')

# %%
example = soup.find_all("tr")[2] # Mbappé

# %%
attributes = [td.get_text() for td in example.find_all("td")]

# %%
attributes
# Out:
# ['\n\n\n\nKylian Mbappé\n\nnormal\n\n',
#  '\n\n91\n\n',
#  '\nST\nCF, LW\n',
#  '\n205K\n5.67%\n',
#  '\n185K\n15.62%\n',
#  '',
#  '4',
#  '5',
#  'H / L',
#  '\n97\n',
#  '\n90\n',
#  '\n80\n',
#  '\n92\n',
#  '\n36\n',
#  '\n78\n',
#  '3,451',
#  '2250',
#  '\n182cm | 6\'0"\nMostly Explosive',
#  '']

# %%
def flatten_list(list_):
    output = []
    for sublist in list_:
        output.extend(sublist)

    return output

# %%
attributes = [i.strip() for i in attributes]

# %%
attributes
# Out:
# ['Kylian Mbappé\n\nnormal',
#  '91',
#  'ST\nCF, LW',
#  '205K\n5.67%',
#  '185K\n15.62%',
#  '',
#  '4',
#  '5',
#  'H / L',
#  '97',
#  '90',
#  '80',
#  '92',
#  '36',
#  '78',
#  '3,451',
#  '2250',
#  '182cm | 6\'0"\nMostly Explosive',
#  '']

# %%
attributes = flatten_list([i.split("\n") for i in attributes])

# %%
attributes
# Out:
# ['Kylian Mbappé',
#  '',
#  'normal',
#  '91',
#  'ST',
#  'CF, LW',
#  '205K',
#  '5.67%',
#  '185K',
#  '15.62%',
#  '',
#  '4',
#  '5',
#  'H / L',
#  '97',
#  '90',
#  '80',
#  '92',
#  '36',
#  '78',
#  '3,451',
#  '2250',
#  '182cm | 6\'0"',
#  'Mostly Explosive',
#  '']

# %%
attributes = flatten_list([i.split("\\") for i in attributes])

# %%
attributes
# Out:
# ['Kylian Mbappé',
#  '',
#  'normal',
#  '91',
#  'ST',
#  'CF, LW',
#  '205K',
#  '5.67%',
#  '185K',
#  '15.62%',
#  '',
#  '4',
#  '5',
#  'H / L',
#  '97',
#  '90',
#  '80',
#  '92',
#  '36',
#  '78',
#  '3,451',
#  '2250',
#  '182cm | 6\'0"',
#  'Mostly Explosive',
#  '']

# %%
attributes = [item.strip() for item in attributes if item.strip() != ""]

# %%
attributes
# Out:
# ['Kylian Mbappé',
#  'normal',
#  '91',
#  'ST',
#  'CF, LW',
#  '205K',
#  '5.67%',
#  '185K',
#  '15.62%',
#  '4',
#  '5',
#  'H / L',
#  '97',
#  '90',
#  '80',
#  '92',
#  '36',
#  '78',
#  '3,451',
#  '2250',
#  '182cm | 6\'0"',
#  'Mostly Explosive']

# %%
player_information = example.find_all("div")[0].find_all("a")

# %%
player_information = example.find_all("span")[0].find_all("a")
player_information = [item['data-original-title'] for item in player_information]
player_information
# Out:
# []

# %%
attributes_names = ["Name", "Club", "Nation", "League", "Rating", "Main_Position", "Alternate_Positions",
                    "Card_Version", "Run_Style", "Price", "Price_Variation", "Skills_Star", "Weak_Foot_Star",
                    "Attack_Workrate", "Defense_Workrate",
                    "Pace / Diving", "Shooting / Handling",
                    "Passing / Kicking", "Dribbling / Reflexes",
                    "Defense / Speed", "Physical / Positioning",
                    "Height", "BodyType", "Popularity", "Base_Stats", "Ingame_Stats"]

# %%
for e, info in enumerate(player_information):
    attributes.insert(e + 1, info)

# %%
player_dict = dict(zip(attributes_names, attributes))
player_dict
# Out:
# {'Name': 'Kylian Mbappé',
#  'Club': 'normal',
#  'Nation': '91',
#  'League': 'ST',
#  'Rating': 'CF, LW',
#  'Main_Position': '205K',
#  'Alternate_Positions': '5.67%',
#  'Card_Version': '185K',
#  'Run_Style': '15.62%',
#  'Price': '4',
#  'Price_Variation': '5',
#  'Skills_Star': 'H / L',
#  'Weak_Foot_Star': '97',
#  'Attack_Workrate': '90',
#  'Defense_Workrate': '80',
#  'Pace / Diving': '92',
#  'Shooting / Handling': '36',
#  'Passing / Kicking': '78',
#  'Dribbling / Reflexes': '3,451',
#  'Defense / Speed': '2250',
#  'Physical / Positioning': '182cm | 6\'0"',
#  'Height': 'Mostly Explosive'}

# %%
def get_player_attributes(row):
    attributes = [td.get_text() for td in row.find_all("td")]
    attributes = [i.strip() for i in attributes]

    attributes = flatten_list([i.split("\n") for i in attributes])
    attributes = flatten_list([i.split("\\") for i in attributes])

    attributes = [item.strip() for item in attributes if item.strip() != ""]

    # Club, League and Nation
    player_information = row.find_all("span")[0].find_all("a")
    player_information = [item['data-original-title'] for item in player_information]

    # Adding to the attributes list
    for e, info in enumerate(player_information):
        attributes.insert(e + 1, info)

    # If a player doesn't have an alternate position
    if len(attributes) == 25:
        attributes.insert(6, None)

    player_dict = dict(zip(attributes_names, attributes))
    return player_dict

       ## Height
    if not find_missing_att(attributes, "|"):
        attributes.insert(-4, "0")
    ## Price Variation:
    if not find_missing_att(attributes, "%"):
        attributes.insert(9, "0")

    # Player doesn't have card version labeled
#     runstyle = ["Controlled", "Explosive", "Lengthy"]
#     if len(attributes) < 25:
#         for style in runstyle:
#             if style in attributes:
#                 index = attributes.index(style)
#                 attributes.insert(index - 1, "Normal")

    # If a player doesn't have an alternate position
    if len(attributes) == 25:
        attributes.insert(6, "0")

    # If the player attributes are complete
    if len(attributes) > 25:
        player_dict = dict(zip(attributes_names, attributes))
        return player_dict

    return None

# %%
gold_players_page = soup.find_all("tr")

# %%
top30_gold_players = list()

for player_row in gold_players_page:
    try:
        player_attributes = get_player_attributes(player_row)
        top30_gold_players.append(player_attributes)
    except IndexError:
        continue

# %%
top30_gold_players = pd.DataFrame(top30_gold_players)
top30_gold_players.head()
# Out:
#                      Name    Club Nation League  Rating Main_Position  \
# 0                     NaN     NaN    NaN    NaN     NaN           NaN
# 1          Erling Haaland  normal     91     ST      CF         25.5K
# 2           Kylian Mbappé  normal     91     ST  CF, LW          205K
# 3  Alexia Putellas Segura  normal     91     CM      LW        29.75K
# 4         Kevin De Bruyne  normal     91     CM     CAM           25K
#
#   Alternate_Positions Card_Version Run_Style Price  ... Attack_Workrate  \
# 0                 NaN          NaN       NaN   NaN  ...             NaN
# 1               1.92%       23.25K     2.11%     3  ...              93
# 2               5.67%         185K    15.62%     4  ...              90
# 3               1.65%        29.5K         5     5  ...              91
# 4               1.96%          22K     8.33%     5  ...              88
#
#   Defense_Workrate Pace / Diving Shooting / Handling Passing / Kicking  \
# 0              NaN           NaN                 NaN               NaN
# 1               66            80                  45                88
# 2               80            92                  36                78
# 3               92            72                  78               851
# 4               94            87                  65                78
#
#   Dribbling / Reflexes Defense / Speed Physical / Positioning  \
# 0                  NaN             NaN                    NaN
# 1                2,723            2191           195cm | 6'5"
# 2                3,451            2250           182cm | 6'0"
# 3                 2466    173cm | 5'8"     Avg & Normal(67kg)
# 4                2,175            2349          181cm | 5'11"
#
#              Height BodyType
# 0               NaN      NaN
# 1    Mostly Lengthy      NaN
# 2  Mostly Explosive      NaN
# 3  Mostly Explosive      NaN
# 4        Controlled      NaN
#
# [5 rows x 23 columns]

# %%
def find_missing_att(list_att, sep):
    '''Iterates for the attributes list and  returns False if doesn't contain.
    If the function find the separator in an item it will break the loop and
    the value will keep his True value, meaning that it found and the player has
    the attribute.'''
    for att in list_att:
        value = sep in att
        if value:
            break

    return value

# %%
for player_row in gold_players_page:
    try:
        player_attributes = get_player_attributes(player_row)
        top30_gold_players.append(player_attributes)
    except IndexError:
        continue

# %%
def authentication_page(page):
    headers = {'User-Agent': 'Mozilla/5.0'}
    req = Request(page, headers=headers)
    response = urlopen(req)
    html = response.read()
    soup_a = BeautifulSoup(html, 'html.parser')
    return soup_a

# %%
def iterate_for_page(index):

    # Authentication
    soup_p = authentication_page("https://www.futbin.com/players?page=")

    # Getting the players from the page
    page_players = soup_p.find_all("tr")
    page_dataframe = list()

    # Iteration
    for player_row in page_players:
        try:
            player_attributes = get_player_attributes(player_row)
            if player_attributes:
                page_dataframe.append(player_attributes)
        except:
            continue

    page_dataframe = pd.DataFrame(page_dataframe)
    return page_dataframe

# %%
def iterate_for_page(index, gender):
    page_url = "https://www.futbin.com/players?page=" + str(index) + "&gender=" + gender

    # Authentication
    soup_p = authentication_page(page_url)

    # Getting the players from the page
    page_players = soup_p.find_all("tr")
    page_dataframe = list()

    # Iteration
    for player_row in page_players:
        try:
            player_attributes = get_player_attributes(player_row)
            if player_attributes:
                page_dataframe.append(player_attributes)
        except:
            continue

    page_dataframe = pd.DataFrame(page_dataframe)
    return page_dataframe
sleep(20)
players_till_10 = pd.DataFrame([])
for i in range(10):
    page_df = iterate_for_page(i + 1, "men")
    players_till_10 = pd.concat([players_till_10, page_df])

# %%
(players_till_10.head())
# Out:
#              Name                 Club Nation League       Rating  \
# 0   Ferenc Puskás  Greats of Game Icon     98     CF           ST
# 1  Kenny Dalglish  Greats of Game Icon     98     ST           CF
# 2         Rivaldo  Greats of Game Icon     98     LW  LM, CAM, CF
# 3         Ronaldo  Greats of Game Icon     98     ST           CF
# 4      Ronaldinho  Greats of Game Icon     98     LW      LM, CAM
#
#   Main_Position Alternate_Positions Card_Version Run_Style  Price  ...  \
# 0             0                   0            5         4  H / M  ...
# 1          3.2M               1.54%         3.9M    22.33%      5  ...
# 2          5.7M                   0            5         5  H / H  ...
# 3             0                   0            5         5  H / M  ...
# 4        12.53M               7.19%       10.15M     1.46%      4  ...
#
#   Attack_Workrate Defense_Workrate Pace / Diving Shooting / Handling  \
# 0              98               53            84               2,352
# 1              98               87            96                  52
# 2              99               51            85                 189
# 3              97               49            84                 378
# 4              95               99            99                  43
#
#   Passing / Kicking Dribbling / Reflexes     Defense / Speed  \
# 0              2558         172cm | 5'8"  Avg & Stocky(72kg)
# 1                83                  250                2513
# 2              2546         186cm | 6'1"   Tall & Lean(75kg)
# 3              2482         183cm | 6'0"            R9(78kg)
# 4                91                  516                2509
#
#   Physical / Positioning              Height              BodyType
# 0       Mostly Explosive                 NaN                   NaN
# 1           173cm | 5'8"  Avg & Normal(73kg)             Explosive
# 2             Controlled                 NaN                   NaN
# 3             Controlled                 NaN                   NaN
# 4          180cm | 5'11"    Ronaldinho(78kg)  Controlled Explosive
#
# [5 rows x 23 columns]

# %%
sleep(20)
men_soup_page = authentication_page("https://www.futbin.com/players?page=1&gender=men")
women_soup_page = authentication_page("https://www.futbin.com/players?page=1&gender=women")

# %% [markdown]
# We will only consider men players.

# %%
men_players = pd.DataFrame([])

# %%
sleep(20)
for i in range(1,  100):
    try:
        page_df = iterate_for_page(i, "men")
        men_players = pd.concat([men_players, page_df])

        if (i) % 6 == 0:
            sleep(15)
        if (i) % 50 == 0:
            print(f"Page {i} Successful")

    except HTTPError as err:
        print("--Erro--", err, sep = "\n")
        sleep(30)

print("\n# -- All Pages Done -- #")
# Out:
# Page 50 Successful
#
# # -- All Pages Done -- #

# %%
men_players.head()
# Out:
#                  Name                 Club Nation League       Rating  \
# 0       Ferenc Puskás  Greats of Game Icon     98     CF           ST
# 1      Kenny Dalglish  Greats of Game Icon     98     ST           CF
# 2             Rivaldo  Greats of Game Icon     98     LW  LM, CAM, CF
# 3             Ronaldo  Greats of Game Icon     98     ST           CF
# 4          Ronaldinho  Greats of Game Icon     98     LW      LM, CAM
# ..                ...                  ...    ...    ...          ...
# 25      Kevin Volland               normal     79     ST      CAM, CF
# 26      Nico Williams               normal     79     RM       LM, RW
# 27      Denis Zakaria               normal     79    CDM           CM
# 28  Davide Zappacosta               normal     79    LWB   LB, RM, LM
# 29    Lucas Zelarayán               normal     79    CAM           CF
#
#    Main_Position Alternate_Positions Card_Version Run_Style  Price  ...  \
# 0              0                   0            5         4  H / M  ...
# 1           3.2M               1.54%         3.9M    22.33%      5  ...
# 2           5.7M                   0            5         5  H / H  ...
# 3              0                   0            5         5  H / M  ...
# 4         12.53M               7.19%       10.15M     1.46%      4  ...
# ..           ...                 ...          ...       ...    ...  ...
# 25           500              11.11%         1.8K         4      3  ...
# 26           700                 10K      566.67%         5      4  ...
# 27           700                 700            3         3  H / H  ...
# 28           900                 80%          700         3      3  ...
# 29           400                 400            3         4  M / L  ...
#
#    Attack_Workrate Defense_Workrate Pace / Diving Shooting / Handling  \
# 0               98               53            84               2,352
# 1               98               87            96                  52
# 2               99               51            85                 189
# 3               97               49            84                 378
# 4               95               99            99                  43
# ..             ...              ...           ...                 ...
# 25              78               78            46                  84
# 26              72               83            33                  60
# 27              76               78            84                  60
# 28              73               74            75                  72
# 29              82               46            65                  16
#
#    Passing / Kicking Dribbling / Reflexes     Defense / Speed  \
# 0               2558         172cm | 5'8"  Avg & Stocky(72kg)
# 1                 83                  250                2513
# 2               2546         186cm | 6'1"   Tall & Lean(75kg)
# 3               2482         183cm | 6'0"            R9(78kg)
# 4                 91                  516                2509
# ..               ...                  ...                 ...
# 25                -2                 2140        174cm | 5'9"
# 26               352                 1956       181cm | 5'11"
# 27              2068         191cm | 6'3"   Tall & Lean(81kg)
# 28                49                 2101        182cm | 6'0"
# 29              2048         172cm | 5'8"  Avg & Normal(70kg)
#
#    Physical / Positioning                Height              BodyType
# 0        Mostly Explosive                   NaN                   NaN
# 1            173cm | 5'8"    Avg & Normal(73kg)             Explosive
# 2              Controlled                   NaN                   NaN
# 3              Controlled                   NaN                   NaN
# 4           180cm | 5'11"      Ronaldinho(78kg)  Controlled Explosive
# ..                    ...                   ...                   ...
# 25     Avg & Stocky(85kg)            Controlled                   NaN
# 26       Avg & Lean(67kg)      Mostly Explosive                   NaN
# 27                Lengthy                   NaN                   NaN
# 28       Avg & Lean(75kg)  Controlled Explosive                   NaN
# 29   Controlled Explosive                   NaN                   NaN
#
# [2970 rows x 23 columns]

# %%
men_players['Rating'] = pd.to_numeric(men_players['Rating'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "ST"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-7ed52247c97d> in <cell line: 1>()
# ----> 1 men_players['Rating'] = pd.to_numeric(men_players['Rating'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     215         coerce_numeric = errors not in ("ignore", "raise")
#     216         try:
# --> 217             values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218                 values,
#     219                 set(),
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "ST" at position 0
